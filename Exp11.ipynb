# %% [markdown]
# <a href="https://colab.research.google.com/github/Giridhar-github/DSML/blob/main/Exp11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aim: Implement problems on natural language processing - Part of Speech
# tagging, N-gram & smoothening and Chunking using NLTK

# %% [markdown]
# Short notes:
#
# The **Natural Language Toolkit (NLTK)** is a platform used for building programs for text analysis. One of the more powerful aspects of the NLTK module is the Part of Speech tagging.
#
# **Part-of-speech (POS)** tagging is a process of converting a sentence to forms – list of words, list of tuples (where each tuple is having a form (word, tag)). The tag in case of is a part-of-speech tag, and signifies whether the word is a noun, adjective, verb, and so on.
#
# **keywords**:
#
# Corpus : Body of text, singular. Corpora is the plural of this.
#
# Lexicon : Words and their meanings.
#
# Token : Each “entity” that is a part of whatever was split up based on rules.

# %% [markdown]
# **Tags and their meanings**
#
# CD cardinal digit
#
# EX existential there (like: “there is” … think of it like “there exists”)
#
# FW foreign word
#
# IN preposition/subordinating conjunction
#
# JJ adjective ‘big’
#
# JJR adjective, comparative ‘bigger’
#
# JJS adjective, superlative ‘biggest’
#
# NN noun, singular ‘desk’
#
# NNS noun plural ‘desks’
#
# NNP proper noun, singular ‘Harrison’
#
# NNPS proper noun, plural ‘Americans’
#
# PDT predeterminer ‘all the kids’
#
# POS possessive ending parent‘s
#
# PRP personal pronoun I, he, she
#
# PRP$ possessive pronoun my, his, hers
#
# RB adverb very, silently,
#
# RBR adverb, comparative better
#
# RBS adverb, superlative best
#
# RP particle give up

# %% [markdown]
# **N-grams** are continuous sequences of words or symbols or tokens in a document. In technical terms, they can be defined as the neighbouring sequences of items in a document.
#
# **Steps for n-gram model:**
#
# Explore the dataset
#
# Feature extraction
#
# Train-test split
#
# Basic pre-processing
#
# Code to generate N-grams
#
# Creating unigrams
#
# Creating bigrams
#
# Creating trigrams

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

stop_words = set(stopwords.words('english'))
  
#Dummy text
txt = "Hello. MCA S3 is fantastic. We learn many new concepts and implement them in our practical exams. "\
"1st of all the data science is a new paper."
  
# sent_tokenize is one of instances of 
# PunktSentenceTokenizer from the nltk.tokenize.punkt module
  
tokenized = sent_tokenize(txt)
for i in tokenized:
      
    # Word tokenizers is used to find the words 
    # and punctuation in a string
    wordsList = nltk.word_tokenize(i)
  
    # removing stop words from wordList
    wordsList = [w for w in wordsList if not w in stop_words] 
  
    #  Using a Tagger. Which is part-of-speech 
    # tagger or POS-tagger. 
    tagged = nltk.pos_tag(wordsList)
  
    print(tagged)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [('Hello', 'NNP'), ('.', '.')]
# [('MCA', 'NNP'), ('S3', 'NNP'), ('fantastic', 'JJ'), ('.', '.')]
# [('We', 'PRP'), ('learn', 'VBP'), ('many', 'JJ'), ('new', 'JJ'), ('concepts', 'NNS'), ('implement', 'JJ'), ('practical', 'JJ'), ('exams', 'NN'), ('.', '.')]
# [('1st', 'CD'), ('data', 'NNS'), ('science', 'NN'), ('new', 'JJ'), ('paper', 'NN'), ('.', '.')]

# %% [markdown]
# N-gram model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use(style='seaborn')

#get the data from https://www.kaggle.com/ankurzing/sentiment-analysis-for-financial-news/version/5

colnames=['Sentiment', 'news']

df=pd.read_csv('all-data.csv',encoding = "ISO-8859-1", names=colnames, header = None)
df.head()
# Out:
#   Sentiment                                               news
# 0   neutral  According to Gran , the company has no plans t...
# 1   neutral  Technopolis plans to develop in stages an area...
# 2  negative  The international electronic industry company ...
# 3  positive  With the new production plant the company woul...
# 4  positive  According to the company 's updated strategy f...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4846 entries, 0 to 4845
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Sentiment  4846 non-null   object
#  1   news       4846 non-null   object
# dtypes: object(2)
# memory usage: 75.8+ KB

# %%
df['Sentiment'].value_counts()
# Out:
# neutral     2879
# positive    1363
# negative     604
# Name: Sentiment, dtype: int64

# %%
y=df['Sentiment'].values
y.shape
# Out:
# (4846,)

# %%
x=df['news'].values
x.shape
# Out:
# (4846,)

# %%
from sklearn.model_selection import train_test_split
(x_train,x_test,y_train,y_test)=train_test_split(x,y,test_size=0.4)
x_train.shape
y_train.shape
x_test.shape
y_test.shape
# Out:
# (1939,)

# %%
df1=pd.DataFrame(x_train)
df1=df1.rename(columns={0:'news'})
df2=pd.DataFrame(y_train)
df2=df2.rename(columns={0:'sentiment'})
df_train=pd.concat([df1,df2],axis=1)
df_train.head()
# Out:
#                                                 news sentiment
# 0  The natural source of isoprene is the tree spe...   neutral
# 1      - Tikkurila inspires you to color your life .   neutral
# 2  The total size of the complex is around 25,000...   neutral
# 3  In the third quarter , net sales increased by ...  positive
# 4  Salcomp 's charger manufacturing plant in Indi...   neutral

# %%
df3=pd.DataFrame(x_test)
df3=df3.rename(columns={0:'news'})
df4=pd.DataFrame(y_test)
df4=df2.rename(columns={0:'sentiment'})
df_test=pd.concat([df3,df4],axis=1)
df_test.head()
# Out:
#                                                 news sentiment
# 0  Both companies ' existing investment plans wil...   neutral
# 1  Ulefos Group is the leading supplier of manhol...   neutral
# 2  Finnair 's Tallinn-based subsidiary , Aero AS ...   neutral
# 3  It is Estonia 's second-largest meat processin...  positive
# 4  The CVs of the proposed members are available ...   neutral

# %%
#removing punctuations
#library that contains punctuation
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
#defining the function to remove punctuation
def remove_punctuation(text):
  if(type(text)==float):
    return text
  ans=""  
  for i in text:     
    if i not in string.punctuation:
      ans+=i    
  return ans

# %%
#storing the puntuation free text in a new column called clean_msg
df_train['news']= df_train['news'].apply(lambda x:remove_punctuation(x))
df_test['news']= df_test['news'].apply(lambda x:remove_punctuation(x))
df_train.head()
#punctuations are removed from news column in train dataset
# Out:
#                                                 news sentiment
# 0  The natural source of isoprene is the tree spe...   neutral
# 1         Tikkurila inspires you to color your life    neutral
# 2  The total size of the complex is around 25000 ...   neutral
# 3  In the third quarter  net sales increased by 1...  positive
# 4  Salcomp s charger manufacturing plant in India...   neutral

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#method to generate n-grams:
#params:
#text-the text for which we have to generate n-grams
#ngram-number of grams to be generated from the text(1,2,3,4 etc., default value=1)
def generate_N_grams(text,ngram=1):
  words=[word for word in text.split(" ") if word not in set(stopwords.words('english'))]  
  print("Sentence after removing stopwords:",words)
  temp=zip(*[words[i:] for i in range(0,ngram)])
  ans=[' '.join(ngram) for ngram in temp]
  return ans

# %%
generate_N_grams("The sun rises in the east",2)
# Out:
# Sentence after removing stopwords: ['The', 'sun', 'rises', 'east']
# ['The sun', 'sun rises', 'rises east']

# %%
generate_N_grams("The sun rises in the east",3)
# Out:
# Sentence after removing stopwords: ['The', 'sun', 'rises', 'east']
# ['The sun rises', 'sun rises east']

# %%
generate_N_grams("The sun rises in the east",4)
# Out:
# Sentence after removing stopwords: ['The', 'sun', 'rises', 'east']
# ['The sun rises east']

# %%
for chunk in pd.read_csv("all-data.csv", chunksize=50,encoding="ISO-8859-1"):
    print(chunk)
# Out:
#      neutral According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .
# 0    neutral  Technopolis plans to develop in stages an area...
# 1   negative  The international electronic industry company ...
# 2   positive  With the new production plant the company woul...
# 3   positive  According to the company 's updated strategy f...
# 4   positive  FINANCING OF ASPOCOMP 'S GROWTH Aspocomp is ag...
# 5   positive  For the last quarter of 2010 , Componenta 's n...
# 6   positive  In the third quarter of 2010 , net sales incre...
# 7   positive  Operating profit rose to EUR 13.1 mn from EUR ...
# 8   positive  Operating profit totalled EUR 21.1 mn , up fro...
# 9   positive  TeliaSonera TLSN said the offer is in line wit...
# 10  positive  STORA ENSO , NORSKE SKOG , M-REAL , UPM-KYMMEN...
# 11  positive  A purchase agreement for 7,200 tons of gasolin...
# 12  positive  Finnish Talentum reports its operating profit ...
# 13  positive  Clothing retail chain Sepp+Æl+Æ 's sales incre...
# 14  positive  Consolidated net sales increased 16 % to reach...
# 15  positive  Foundries division reports its sales increased...
# 16  positive  HELSINKI ( AFX ) - Shares closed higher , led ...
# 17  positive  Incap Contract Manufacturing Services Pvt Ltd ...
# 18  positive  Its board of directors will propose a dividend...
# 19  positive  Lifetree was founded in 2000 , and its revenue...
# 20  positive  ( Filippova ) A trilateral agreement on invest...
# 21  positive  MegaFon 's subscriber base increased 16.1 % in...
# 22  positive  Net income from life insurance doubled to EUR ...
# 23  positive  Net sales increased to EUR193 .3 m from EUR179...
# 24  positive  Net sales surged by 18.5 % to EUR167 .8 m. Tel...
# 25  positive  Nordea Group 's operating profit increased in ...
# 26  positive  Operating profit for the nine-month period inc...
# 27  positive  Operating profit for the nine-month period inc...
# 28  positive  Operating profit for the three-month period in...
# 29  positive  The Brazilian unit of Finnish security solutio...
# 30  positive  The company 's net profit rose 11.4 % on the y...
# 31  positive  The Lithuanian beer market made up 14.41 milli...
# 32  positive  Viking Line 's cargo revenue increased by 5.4 ...
# 33  positive  The fair value of the property portfolio doubl...
# 34  positive  10 February 2011 - Finnish media company Sanom...
# 35  positive  A Helsinki : ELIiV today reported EPS of EUR1 ...
# 36  positive  Aspo Plc STOCK EXCHANGE RELEASE February 11 , ...
# 37  positive  Commission income increased by 22 % to EUR 4.4...
# 38  positive  In January , traffic , measured in revenue pas...
# 39  positive  In January-September 2010 , Fiskars ' net prof...
# 40  positive  Net income from life insurance rose to EUR 16....
# 41  positive  Nyrstar has also agreed to supply to Talvivaar...
# 42  positive  Sales for both the Department Store Division a...
# 43  positive         Sales have risen in other export markets .
# 44  positive  Sales increased due to growing market rates an...
# 45  positive  The agreement strengthens our long-term partne...
# 46  positive  The agreement was signed with Biohit Healthcar...
# 47  positive  The company also estimates the already carried...
# 48  positive  The company 's order book stood at 1.5 bln eur...
# 49  positive  The company said that paper demand increased i...
#      neutral According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .
# 50  positive  The world 's second largest stainless steel ma...
# 51  positive  Within the framework of the partnership , Noki...
# 52  positive  Seppala 's revenue increased by 0.2 % to EUR10...
# 53  positive  Shares of Standard Chartered ( STAN ) rose 1.2...
# 54  positive  Shares of Nokia Corp. rose Thursday after the ...
# 55  positive  In its financial report , published on Friday ...
# 56  positive  Sales for the Department Store Division increa...
# 57   neutral  At the request of Finnish media company Alma M...
# 58   neutral  In Sweden , Gallerix accumulated SEK denominat...
# 59   neutral  The company supports its global customers in d...
# 60   neutral  When this investment is in place , Atria plans...
# 61   neutral  `` The new agreement is a continuation to thea...
# 62  positive  At first the contract envisaged the constructi...
# 63   neutral  In June it sold a 30 percent stake to Nordstje...
# 64  positive  KESKO CORPORATION STOCK EXCHANGE RELEASE 28.02...
# 65  positive  Sponda Plc Stock Exchange Release 5 December 2...
# 66   neutral  STOCK EXCHANGE ANNOUNCEMENT 20 July 2006 1 ( 1...
# 67  positive  The contract covers HDO platform , AC800 and C...
# 68   neutral  The new plant is planned to have an electricit...
# 69  positive  The OMX Helsinki 25 index was up 0.92 pct at 2...
# 70   neutral  - So , the sales growth of cars considerably i...
# 71   neutral  A maximum of 666,104 new shares can further be...
# 72   neutral  As a result of the share issue , the number of...
# 73   neutral  Finnish real estate investor Sponda Plc said o...
# 74   neutral  On the route between Helsinki in Finland and T...
# 75   neutral  Other measures included increasing synergies a...
# 76  positive  Rinkuskiai raised the sales by 18.1 percent , ...
# 77   neutral  TELECOMWORLDWIRE-7 April 2006-TJ Group Plc sel...
# 78  positive  TELECOMWORLDWIRE-7 April 2006-TJ Group Plc sel...
# 79   neutral  The 718,430 new Series A shares will become su...
# 80   neutral  The fuel purchase contracts have been signed w...
# 81   neutral  Tiimari operates 194 stores in six countries -...
# 82  positive  Under this agreement Biohit becomes a focus su...
# 83  positive  The combination of all services enabling us to...
# 84   neutral  No blind-spots coming from 1 vantage point all...
# 85  positive  The company still expects its turnover in 2010...
# 86  positive  The acquisition will considerably increase Kem...
# 87  positive  In January-September 2007 , Finnlines ' net sa...
# 88  positive  Adjusted for changes in the Group structure , ...
# 89  positive  `` The change will optimize the operational ef...
# 90  positive  `` They would invest not only in the physical ...
# 91  positive  4 February 2011 - Finnish broadband data commu...
# 92  positive  Finnish Aktia Group 's operating profit rose t...
# 93  positive  Finnish Bank of +_land 's consolidated net ope...
# 94  positive  Finnish financial group Aktia reports operatin...
# 95  positive  Finnish high technology provider Vaahto Group ...
# 96  positive  Net sales of Finnish food industry company L+Æ...
# 97  positive  An individual promotion also generated slightl...
# 98  positive  Biohit already services many current Genesis c...
# 99  positive  Both operating profit and turnover for the thr...
#       neutral According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .
# 100  positive  Circulation revenue has increased by 5 % in Fi...
# 101  positive  Clothing chain Sepp+Æl+Æ 's net sales increase...
# 102  positive  Construction volumes meanwhile grow at a rate ...
# 103  positive  Finnish and Swedish construction markets are s...
# 104  positive  However , Biohit estimates its total net sales...
# 105  positive  In 2009 , Fiskars ' cash flow from operating a...
# 106  positive  In Lithuania , operating profit rose to EUR 19...
# 107  positive  In the fourth quarter of 2008 , net sales incr...
# 108  positive  International sales rose by 59.8 % to EUR 1,24...
# 109   neutral  Kalmar Espana generated net sales of some 11.3...
# 110  positive  Net sales grew in the period to  x20ac 402 mil...
# 111  positive  Net sales increased to EUR655m in April to Jun...
# 112  positive  Net sales rose by 25.5 % year-on-year to EUR59...
# 113  positive  Net sales totaled EUR 93.6 mn , up from EUR 93...
# 114  positive  Nokia also noted the average selling price of ...
# 115  positive  Operating profit increased by 145.1 % to EUR 8...
# 116  positive  Operating profit margin increased from 11.2 % ...
# 117  positive  Operating profit rose to EUR 3.11 mn from EUR ...
# 118  positive  Operating profit rose to EUR 5mn from EUR 2.8 ...
# 119  positive  Operating profit was EUR 24.5 mn , up from EUR...
# 120  positive  Ramirent 's net sales in the second quarterend...
# 121  positive  Revenue grew by 2 percent to  x20ac 580 millio...
# 122  positive  Ruukki announced that it has signed an agreeme...
# 123  positive  Ruukki 's delivery volumes and selling prices ...
# 124  positive  Sanoma Magazines ' net sales are estimated to ...
# 125  positive  The bank forecasts Finland 's GDP will grow by...
# 126  positive  The circuit 's overall production rate on a we...
# 127  positive  The company 's consolidated operating profit a...
# 128  positive  The Department Store Division reported an incr...
# 129  positive  The fair value of the company 's investment pr...
# 130  positive  The last quarter was the best quarter of 2009 ...
# 131  positive  The major breweries increased their domestic b...
# 132  positive  The transaction doubles Tecnomens workforse , ...
# 133  positive  - Operating profit rose by 26.9 % to EUR 105.8...
# 134  positive  `` After this purchase , Cramo will become the...
# 135  positive  `` The priority for 2009 was to strengthen the...
# 136  positive  `` The purchase of the operations is part of Y...
# 137  positive  21 October 2010 - Finnish fishing tackle compa...
# 138   neutral  A structures BIM ( building information modeli...
# 139  positive  According to Finnish Metso Minerals , the valu...
# 140  positive  Finnish Aldata Solution has signed a contract ...
# 141  positive  Finnish Bank of +_land reports its operating p...
# 142  positive  Finnish financial group Aktia 's operating pro...
# 143  positive  Finnish forest machinery manufacturer Ponsse '...
# 144  positive  Finnish KCI Konecranes has raised its net sale...
# 145  positive  Finnish Okmetic that manufactures and processe...
# 146  positive  Finnish pharmaceuticals company Orion 's net s...
# 147  positive  Finnish Ponsse has signed an agreement with Ba...
# 148  positive  South African Sappi will become the largest fo...
# 149  positive  According to Deputy MD Pekka Silvennoinen the ...
#       neutral According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .
# 150  positive  According to HKScan Finland , the plan is to i...
# 151  positive  Advertising and circulation revenues grew by 3...
# 152  positive  After the takeover , Cramo will become the sec...
# 153  positive  Again , the most significant sales increase of...
# 154  positive  Alma Media expects its net sales to increase a...
# 155  positive  Also Lemmink+Æinen 's profit for accounting pe...
# 156  positive  At the end of March 2007 , the group 's order ...
# 157  positive  At the same time profit of the company increas...
# 158   neutral  Aviation Systems Maintenance is based in Kansa...
# 159  positive  Besides we have increased the share of meat in...
# 160  positive  Both operating profit and net sales for the 12...
# 161  positive  Both operating profit and net sales for the 12...
# 162  positive  Both operating profit and net sales for the 12...
# 163  positive  Both operating profit and net sales for the 12...
# 164  positive  Both operating profit and net sales for the ni...
# 165  positive  Both operating profit and net sales for the si...
# 166  positive  Both operating profit and net sales for the si...
# 167  positive  Both operating profit and net sales for the si...
# 168  positive  Both operating profit and net sales for the si...
# 169  positive  Both operating profit and net sales for the th...
# 170  positive  Both operating profit and net sales for the th...
# 171  positive  Both operating profit and sales for the three-...
# 172  positive  Both operating profit and turnover for the nin...
# 173  positive  Both operating profit and turnover for the six...
# 174  positive  Both operating profit and turnover for the six...
# 175  positive                         Cargo volume grew by 7 % .
# 176  positive      Cargo volume increased by approximately 5 % .
# 177  positive  comparable operating profit totaled EUR 854mn ...
# 178  positive  Digia said its consolidated net sales for Janu...
# 179  positive  Diluted earnings per share ( EPS ) rose to EUR...
# 180  positive  Diluted earnings per share ( EPS ) rose to EUR...
# 181  positive  Diluted earnings per share ( EPS ) rose to EUR...
# 182  positive  Diluted earnings per share ( EPS ) rose to EUR...
# 183  positive       Diluted EPS rose to EUR3 .68 from EUR0 .50 .
# 184  positive           EBIT margin was up from 1.4 % to 5.1 % .
# 185   neutral  Editor 's note : Grimaldi generated a 1.7 bln ...
# 186  positive  EPS for the quarter was EUR0 .00 , as compared...
# 187  positive  EPS from continuing operations came in at 0.30...
# 188  positive  Equity ratio was 60.9 % compared to 54.2 % In ...
# 189  positive  EUR928 ,000 in Q1 2010 6 May 2010 - Finnish te...
# 190  positive  Finland-based Elcoteq SE , a privately held pr...
# 191  positive  Finnish cutlery and hand tools maker Fiskars O...
# 192  positive  Finnish department store chain Stockmann Oyj A...
# 193  positive  Finnish lifting equipment maker Konecranes Oyj...
# 194  positive  Finnish messaging solutions developer Tecnomen...
# 195  positive  Finnish metal industry solutions supplier Outo...
# 196  positive  Finnish metal products company Componenta Oyj ...
# 197  positive  Finnish office supplies and computer accessori...
# 198  positive  Finnish security and privacy software solution...
# 199  positive  Finnish silicon wafer technology company Okmet...
#       neutral According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .
# 200  positive  Finnish software developer Done Solutions Oyj ...
# 201  positive  First quarter underlying operating profit rose...
# 202  positive  Following the acquisition , Relacom will stren...
# 203  positive  For the first nine months of 2010 , the compan...
# 204  positive  HELSINKI ( AFX ) - Retail and wholesale group ...
# 205  positive  However , net sales in 2010 are seen to have g...
# 206  positive  However , sales returned to growth in April-Ju...
# 207  positive  Ragutis , which is controlled by the Finnish b...
# 208  positive  Svyturys-Utenos Alus , which is controlled by ...
# 209   neutral  In 2007 , Contempus generated revenue of NOK 6...
# 210  positive  In addition , Kone signed a two-year maintenan...
# 211  positive  In December alone , the members of the Lithuan...
# 212  positive  In January-September 2009 , the Group 's net i...
# 213  positive  In Q1 of 2010 , Bank of +_land 's net interest...
# 214  positive  In Sweden , operating profit for the period un...
# 215  positive  In the fourth quarter of 2009 , Orion 's net p...
# 216  positive  In the second quarter of 2010 , the group 's n...
# 217  positive  In the second quarter of 2010 , the group 's n...
# 218  positive  In the third quarter , net sales increased by ...
# 219  positive  In the third quarter , net sales increased by ...
# 220   neutral  Incap estimates it will generate a revenue of ...
# 221  positive  Its market share widened to 48.51 percent from...
# 222   neutral  Its total annual revenue comes up to about 160...
# 223  positive  Kesko Agro Eesti , the retailer and wholesaler...
# 224  positive  Kesko 's car import and retailing business , V...
# 225  positive  Kone 's net sales rose by some 14 % year-on-ye...
# 226  positive  ( ADP News ) - Feb 11 , 2009 - Finnish managem...
# 227  positive  ( ADP News ) - Feb 12 , 2009 - Finnish IT solu...
# 228  positive  ( ADP News ) - Feb 6 , 2009 - Finnish fishing ...
# 229  positive  ( ADP News ) - Nov 5 , 2008 - Finnish electron...
# 230  positive  ( ADP News ) - Oct 29 , 2008 - Finnish lifting...
# 231  positive  Metso expects its net sales to increase by abo...
# 232   neutral  M-real generated a turnover of EUR5 .6 bn in 2...
# 233  positive  Neste Oil Corp. has signed long-term procureme...
# 234  positive  Net interest income increased by 4.5 % to EUR ...
# 235  positive  Net interest income was EUR 152.2 mn , up from...
# 236  positive  Net interest income was EUR 39.3 mn , up from ...
# 237  positive  Net sales of the Vegetable Oil Business rose t...
# 238  positive  Nokia Multimedia 's net sales totaled EUR 5.7 ...
# 239  positive  Operating income rose to EUR 696.4 mn from EUR...
# 240  positive  Operating profit of Kauppalehti group rose to ...
# 241  positive  Operating profit rose from EUR 1.94 mn to EUR ...
# 242  positive  Operating profit rose to 22.1 mln eur from 19....
# 243  positive  Operating profit rose to EUR 1.6 mn from EUR 1...
# 244  positive  Operating profit rose to EUR 103.4 mn from EUR...
# 245  positive  Operating profit rose to EUR 13.5 mn from EUR ...
# 246  positive  Operating profit rose to EUR 26.7 mn from EUR ...
# 247  positive  Operating profit rose to EUR 27.8 mn from EUR ...
# 248  positive  Operating profit rose to EUR 3.2 mn from EUR 1...
# 249  positive  Operating profit rose to EUR 4.7 mn from EUR 3...
#       neutral According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .
# 250  positive  Operating profit rose to EUR 4.7 mn from EUR 4...
# 251  positive  Operating profit rose to EUR 9.2 mn from EUR 6...
# 252  positive  Operating profit rose to EUR2 .4 m from EUR1 ....
# 253  positive  Operating profit surged to EUR21m from EUR106 ...
# 254  positive  Operating profit totaled EUR 37,7 mn , up slig...
# 255  positive  Operating profit totaled EUR 5.5 mn , up from ...
# 256  positive  Operating profit was EUR 11.4 mn , up from EUR...
# 257  positive  Operating profit was EUR 139.7 mn , up 23 % fr...
# 258  positive  Order intake grew by 40 % year-on-year and 30 ...
# 259  positive  Orders received grew by 55 % year-on-year to E...
# 260  positive  Orion Pharma 's operating profit increased by ...
# 261  positive  Passenger volumes rose by 8.4 % in the account...
# 262  positive  Passenger-related revenue rose by 5.1 % to EUR...
# 263  positive  Press release 9 October 2009 Ruukki has signed...
# 264  positive  Pretax profit rose to EUR 0.6 mn from EUR 0.4 ...
# 265  positive  Pretax profit rose to EUR 1,019 mn from EUR 1,...
# 266  positive  Pretax profit rose to EUR 17.8 mn from EUR 14....
# 267  positive  Pre-tax profit totaled EUR 397.4 mn , up from ...
# 268  positive  Previously , the company had guided for EBIT a...
# 269  positive  Previously the company has estimated its opera...
# 270  positive  Profit for the period totaled EUR 39.4 mn , up...
# 271  positive  Profit for the period was EUR 5.9 mn , up from...
# 272  positive  Profit for the period was EUR 9.8 mn , up from...
# 273  positive  Revenue grew 12 percent to (  x20ac ) 3.6 bill...
# 274  positive  Revenue in July to September grew 14 percent t...
# 275  positive  Revenues at the same time grew 14 percent to 4...
# 276  positive  Ruukki has signed a contract to deliver and in...
# 277  positive  Sales in Latin America increased by 42 % to EU...
# 278  positive                 Sales of clothing developed best .
# 279  positive  Sanoma Magazines Finland 's net sales grew to ...
# 280  positive  Satama 's net profit for the third quarter of ...
# 281  positive  Section : Regional News - The demand in Finnai...
# 282  positive  Svyturys-Utenos Alus , which is controlled by ...
# 283  positive  That would be an increase from estimated sales...
# 284  positive  The agreement expands Tekla Structures ' scope...
# 285  positive  The aim is to increase sales by at least one f...
# 286  positive  The chain posted sales of 298 million euros fo...
# 287  positive  The company expects its net sales in 2008 to i...
# 288  positive  The company expects its net sales in the first...
# 289  positive  The company is in the process of building a ne...
# 290  positive  The company 's operating income ( EBIT ) total...
# 291  positive  The EPS outlook was increased by 5.6 pct for 2...
# 292  positive  The fair value of the investment properties to...
# 293  positive  The Finnish government announced Wednesday tha...
# 294   neutral  The firm generated sales of 187 mln eur in 2005 .
# 295  positive  The German company has also signed a code shar...
# 296  positive  The Helsinki-based company , which also owns t...
# 297  positive  The increase in capital stock has been registe...
# 298  positive  The operating profit for Grain Trading increas...
# 299  positive  The stock rose for a second day on Wednesday b...
#       neutral According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .
# 300  positive  The stock rose for a third day on Tuesday brin...
# 301  positive  The transaction is in line with Aspo 's strate...
# 302  positive  The transactions would increase earnings per s...
# 303  positive  There has been some recovery of the base metal...
# 304  positive  This new representation extends Comptel 's glo...
# 305  positive  TietoEnator itself uses Nokia 's Intellisync M...
# 306  positive  Total operating revenue grew by 27.6 % year-on...
# 307  positive  Vacon 's cash flow from operations grew to EUR...
# 308   neutral  Vacon will supply drives to Ruselprom in the p...
# 309  positive  We also strengthen our existing partnership wi...
# 310  positive  Via the Satlan acquisition , Teleste plans to ...
# 311  positive  With the acquisition , the company will expand...
# 312  positive  With the extension of the new contract for a f...
# 313  positive  YIT says the acquisition is a part of its stra...
# 314  positive  `` BasWare 's product sales grew strongly in t...
# 315  positive  `` The second quarter of 2010 was the firstqua...
# 316  positive  `` The transaction strengthens our position .....
# 317  positive  1 February 2011 - Finnish textile and clothing...
# 318   neutral  Finnish Componenta has published its new long-...
# 319  positive  Finnish Larox has signed a contract with the T...
# 320  positive  Affecto expects its net sales for the whole 20...
# 321  positive  Cash flow from operations rose to EUR 52.7 mn ...
# 322  positive  Commission income rose by 25.7 % to EUR 16.1 m...
# 323  positive  Componenta 's objective with this agreement is...
# 324  positive  Earnings per share for January-June 2010 were ...
# 325  positive  Earnings per share EPS rose to EUR 0.11 from E...
# 326  positive  Elisa said mobile subscriptions grew 7 percent...
# 327  positive  EPS for the quarter came in at 0.36 eur , up f...
# 328  positive               EPS grew to 0.04 eur from 0.02 eur .
# 329  positive  Exports grew 16.5 percent to 19.1 million lite...
# 330  positive  Finnish investment group Panostaja Oyj said it...
# ...
# 4735  negative  However , the net sales declined to EUR 803.6 ...
# 4736  negative  In food trade , sales amounted to EUR320 .1 m ...
# 4737  negative  In January-November 2009 , the group 's sales ...
# 4738  negative  In July-September 2009 , Konecranes ' sales de...
# 4739  negative  In sales volume , Coca-Cola 's market share ha...
# 4740  negative  In September alone , the market declined by 10...
# 4741  negative  In the Baltic countries , development of opera...
# 4742  negative  In the Baltic countries , sales fell by 40.2 %...
# 4743  negative   In the Baltic countries , sales fell by 42.6 % .
# 4744  negative  Nokia s U.S. shares were 3.3 percent lower at ...
# 4745  negative  Nokia shares hit 13.21 euros on Friday , down ...
# 4746  negative  Operating profit decreased to EUR 11.2 mn from...
# 4747  negative  Operating profit decreased to nearly EUR 1.7 m...
# 4748  negative  Operating profit fell to EUR 20.3 mn from EUR ...
# 4749  negative  Operating profit in the fourth quarter fell to...
#        neutral According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .
# 4750  negative  Operating profit totaled EUR 3.8 mn , down fro...
# 4751  negative  Operating profit totaled EUR 6.7 mn , down fro...
# 4752  negative  Operating profit totaled EUR 9.4 mn , down fro...
# 4753  negative  Operating profit totalled EUR 1.22 mn , down f...
# 4754  negative  Operating profit totalled EUR 30.2 mn , down f...
# 4755  negative  Operating profit totalled EUR 9.0 mn , down fr...
# 4756  negative  Operating profit totalled EUR 9.6 mn , down fr...
# 4757  negative  Operating profit was EUR -0.1 mn , down from E...
# 4758  negative  Profit for the period was EUR 10.9 mn , down f...
# 4759  negative  Revenue was slightly down , at  x20ac 495 mill...
# 4760  negative  Sales at the Tiimari business went down by 8 %...
# 4761  negative        Sales by Seppala diminished by 6 per cent .
# 4762  negative  Talentum 's net sales in September were smalle...
# 4763  negative  The company 's previous estimate was for a low...
# 4764  negative  The company 's profit totaled Ls 578,100 in H1...
# 4765  negative  The company said that sales in the three month...
# 4766  negative  The operating margin came down to 2.4 % from 5...
# 4767  negative  The operating margin of Aker Yards Cruise & Fe...
# 4768  negative  The terms of the aforementioned funding are co...
# 4769  negative  The total capital of funds managed by the bank...
# 4770  negative  UPM stock fell 3 percent to EURO 12.49 $ 17.24...
# 4771  negative  YIT 's Baltic sales in the first three quarter...
# 4772  positive  According to the company , its operating profi...
# 4773  positive  `` I am extremely delighted with this project ...
# 4774  positive  The apartment block will be well-located , in ...
# 4775   neutral  The share issue , derogating from the pre-empt...
# 4776   neutral  `` EB Tough VoIP was designed to fulfill the c...
# 4777   neutral  `` Low energy consumption and flexible loading...
# 4778   neutral  The antibody , administered at repeated doses ...
# 4779  positive  The antibody , given at repeated doses of up t...
# 4780  negative  ADPnews - Sep 28 , 2009 - Finnish silicon wafe...
# 4781  negative  - Demand for fireplace products was lower than...
# 4782  negative  Currently , the company foresees its pre-tax p...
# 4783  negative  However , the orders received during the perio...
# 4784  negative  The announcement pushed Freenet shares down 6....
# 4785  positive  Danske Bank A-S DANSKE DC jumped 3.7 percent t...
# 4786  positive  Our superior customer centricity and expertise...
# 4787  negative  According to the company , in addition to norm...
# 4788  negative  Changes in the market situation and tougher pr...
# 4789  negative  In the building and home improvement trade , s...
# 4790  negative  In the building and home improvement trade , n...
# 4791  negative  In the building and home improvement trade , s...
# 4792  negative  Finnish Suominen Corporation that makes wipes ...
# 4793   neutral  The hull of the vessel was built one block at ...
# 4794  negative  The net sales of the whole fiscal year 2008 wi...
# 4795  negative  Sales at the unit slumped last year after the ...
# 4796  negative  The steelmaker said that the drop in profit wa...
# 4797  negative  Nokia 's share price fell less than one percen...
# 4798  negative  In February the Elcoteq group sold its St Pete...
# 4799  negative  `` Operating profit declined mainly due to the...
#        neutral According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .
# 4800  negative  Operating profit in the fourth quarter went do...
# 4801   neutral  The manager is critical of politicians ' failu...
# 4802  negative  UPM-Kymmene Corp. , the world 's largest maker...
# 4803   neutral  In Finland , the launch of tie-in sales of 3G ...
# 4804   neutral               `` I 'm not sure what 's happening .
# 4805   neutral  As such , the space has blond wood floors ( un...
# 4806   neutral    The winner does not have to be present to win .
# 4807  negative  Bosse added that Trygvesta does not have the f...
# 4808   neutral  Pentik+Æinen emphasises that the most of the i...
# 4809  negative  Finnish meat company Atria can no longer promi...
# 4810  negative  Thanks to the internet , consumers compare pro...
# 4811   neutral  Because expenditures must be justified to pass...
# 4812  negative  `` Capital expenditure on energy efficiency ha...
# 4813  negative  Due to the rapid decrease in net sales , perso...
# 4814  negative  Operating profit excluding non-recurring items...
# 4815  negative  Finnish waste management and cleaning group La...
# 4816  negative  Qualcomm estimated a first-quarter profit betw...
# 4817  negative  Finnish-Swedish Stora Enso does not understand...
# 4818   neutral  Nevertheless , the development can not be allo...
# 4819   neutral  Besides , as there is no depositor preference ...
# 4820  negative  Operating margin , however , slipped to 14.4 %...
# 4821  positive  The 2015 target for net sales has been set at ...
# 4822   neutral  It holds 38 percent of Outokumpu 's shares and...
# 4823  negative  As a result of these transactions , the aggreg...
# 4824  negative  have notified that as a result of the Company ...
# 4825   neutral  Mobile communication and wireless broadband pr...
# 4826  negative  External net sales from the printing business ...
# 4827  negative  Seven-month sales of Ragutis , which is contro...
# 4828  negative  The OMX Helsinki index was 0.33 pct lower at 9...
# 4829  negative  The OMX Helsinki index was down 0.34 pct at 8,...
# 4830  negative  Repeats sees 2008 operating profit down y-y ( ...
# 4831  negative  Comparable operating profit totaled EUR 4.7 mn...
# 4832  negative  In Finland 's Hobby Hall 's sales decreased by...
# 4833  negative  Hobby Hall 's sales decrease 26 pct due to imp...
# 4834  negative  In the Baltic states the company reports net s...
# 4835  negative  Operating profits in the half were  0.8 m , do...
# 4836  negative  Sales in Finland decreased by 2.0 % , and inte...
# 4837  negative  The company said that its comparable operating...
# 4838  negative  Operating result for the 12-month period decre...
# 4839  negative  HELSINKI Thomson Financial - Shares in Cargote...
# 4840  negative  LONDON MarketWatch -- Share prices ended lower...
# 4841   neutral  Rinkuskiai 's beer sales fell by 6.5 per cent ...
# 4842  negative  Operating profit fell to EUR 35.4 mn from EUR ...
# 4843  negative  Net sales of the Paper segment decreased to EU...
# 4844  negative  Sales in Finland decreased by 10.5 % in Januar...
